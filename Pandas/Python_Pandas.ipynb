# %%
import pandas as pd

# %%
cars = {"Brand": ["honda", "toyota", "lexus", "maruti", "ford"], 
       "Price": [12000, 4500, 56000, 454545, 87878]}

# %%
carsdf = pd.DataFrame(cars)
carsdf
# Out:
#     Brand   Price
# 0   honda   12000
# 1  toyota    4500
# 2   lexus   56000
# 3  maruti  454545
# 4    ford   87878

# %%
my_list = ["names", ["manthan", "sjcbsj", 'hbj', ['nvdnb']], "age", 25]
fd = pd.DataFrame(my_list)
fd
# Out:
#                                  0
# 0                            names
# 1  [manthan, sjcbsj, hbj, [nvdnb]]
# 2                              age
# 3                               25

# %%
names = ['manthan', 'ajay', 'vincent', 'mohit', 'rohit']
age   = [25,36,36,25,25]

my_df = pd.DataFrame( list(zip(names, age)))
my_df
# Out:
#          0   1
# 0  manthan  25
# 1     ajay  36
# 2  vincent  36
# 3    mohit  25
# 4    rohit  25

# %%
df = pd.read_csv("C:/Users/USER/Downloads/Jupyter-Notebooks/Space_Corrected.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0           0             0       SpaceX
# 1           1             1         CASC
# 2           2             2       SpaceX
# 3           3             3    Roscosmos
# 4           4             4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# ...

# %%
df.tail(5)
# Out:
#       Unnamed: 0  Unnamed: 0.1 Company Name  \
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                        Location                       Datum  \
# 4319   LC-18A, Cape Canaveral AFS, Florida, USA  Wed Feb 05, 1958 07:33 UTC
# 4320   LC-26A, Cape Canaveral AFS, Florida, USA  Sat Feb 01, 1958 03:48 UTC
# 4321   LC-18A, Cape Canaveral AFS, Florida, USA  Fri Dec 06, 1957 16:44 UTC
# 4322  Site 1/5, Baikonur Cosmodrome, Kazakhstan  Sun Nov 03, 1957 02:30 UTC
# 4323  Site 1/5, Baikonur Cosmodrome, Kazakhstan  Fri Oct 04, 1957 19:28 UTC
#
#                           Detail  Status Rocket  Rocket Status Mission
# 4319   Vanguard | Vanguard TV3BU  StatusRetired     NaN        Failure
# 4320         Juno I | Explorer 1  StatusRetired     NaN        Success
# ...

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 4324

# %%
columns
# Out:
# 9

# %%
df[:]
# Out:
#       Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0              0             0       SpaceX
# 1              1             1         CASC
# 2              2             2       SpaceX
# 3              3             3    Roscosmos
# 4              4             4          ULA
# ...          ...           ...          ...
# 4319        4319          4319      US Navy
# 4320        4320          4320         AMBA
# 4321        4321          4321      US Navy
# 4322        4322          4322    RVSN USSR
# 4323        4323          4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Company Name', 'Location', 'Datum',
#        'Detail', 'Status Rocket', ' Rocket', 'Status Mission'],
#       dtype='object')

# %%
df.Detail
# Out:
# 0       Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1                Long March 2D | Gaofen-9 04 & Q-SAT
# 2                 Starship Prototype | 150 Meter Hop
# 3       Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4                         Atlas V 541 | Perseverance
#                             ...
# 4319                       Vanguard | Vanguard TV3BU
# 4320                             Juno I | Explorer 1
# 4321                         Vanguard | Vanguard TV3
# 4322                      Sputnik 8K71PS | Sputnik-2
# 4323                      Sputnik 8K71PS | Sputnik-1
# Name: Detail, Length: 4324, dtype: object

# %%
df[['Status Rocket', 'Company Name']]
# Out:
#       Status Rocket Company Name
# 0      StatusActive       SpaceX
# 1      StatusActive         CASC
# 2      StatusActive       SpaceX
# 3      StatusActive    Roscosmos
# 4      StatusActive          ULA
# ...             ...          ...
# 4319  StatusRetired      US Navy
# 4320  StatusRetired         AMBA
# 4321  StatusRetired      US Navy
# 4322  StatusRetired    RVSN USSR
# 4323  StatusRetired    RVSN USSR
#
# [4324 rows x 2 columns]
